# %%
from PIL import Image

# %%
mac = Image.open('dog.jpg')

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x148 at 0x291BF6D3580>

# %%
mac.size
# Out:
# (200, 148)

# %%
mac.filename
# Out:
# 'dog.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
#cropping images

# %%
mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x291BF8AB850>

# %%
pencils = Image.open('pencils.jpg')

# %%
pencils
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x291BF8ABC10>

# %%
pencils.size
# Out:
# (300, 168)

# %%
x = 0
y = 0

w = 313/2
h = 307/4

# %%
pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=156x77 at 0x291BF8B70A0>

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x148 at 0x291BF6D3580>

# %%
mac.size
# Out:
# (200, 148)

# %%
halfway = 200/2

# %%
x = halfway -50
w = halfway +50

# %%
y = 150
h = 148

# %%
red = Image.open('red.png')

# %%
red
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500 at 0x291BF8AB970>

# %%
red.putalpha(120)

# %%
red
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=500x500 at 0x291BF8AB970>
